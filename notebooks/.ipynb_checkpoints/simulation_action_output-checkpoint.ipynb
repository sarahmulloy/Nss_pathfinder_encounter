# %%
#Import libraries 
import pandas as pd
import numpy as np
import requests
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt


import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO
import re
import random

import warnings
from pandas.errors import SettingWithCopyWarning
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)

# %% [markdown]
# ### import main dataframes

# %%
build_stat= pd.read_csv('../output_data/all_build_base_stats.csv')
#reset index
build_stat= build_stat.set_index('Unnamed: 0', drop=True)
build_stat = build_stat.rename_axis('character_build', axis='index')
build_stat.head(3)
# Out:
#                           ancestry                class  level  strength  \
# character_build
# dwarf barbarian strength     dwarf   barbarian strength      1       2.0
# dwarf fighter strength       dwarf     fighter strength      1       2.0
# dwarf fighter   dexterity    dwarf  fighter   dexterity      1       1.0
#
#                            dexterity  constitution  intelligence  wisdom  \
# character_build
# dwarf barbarian strength         1.0           2.0           1.0     2.0
# dwarf fighter strength           1.0           2.0           1.0     2.0
# dwarf fighter   dexterity        2.0           2.0           1.0     2.0
#
#                            charisma
# character_build
# dwarf barbarian strength        0.0
# dwarf fighter strength          0.0
# dwarf fighter   dexterity       0.0

# %%
build_skill= pd.read_csv('../output_data/all_build_base_skills.csv')
#reset index
build_skill= build_skill.set_index('Unnamed: 0', drop=True)
build_skill = build_skill.rename_axis('character_build', axis='index')
build_skill.head(3)
# Out:
#                           ancestry                class  level  hit points  \
# character_build
# dwarf barbarian strength     dwarf   barbarian strength      1        24.0
# dwarf fighter strength       dwarf     fighter strength      1        22.0
# dwarf fighter   dexterity    dwarf  fighter   dexterity      1        22.0
#
#                            speed  perception  fortitude  reflex  will  \
# character_build
# dwarf barbarian strength    20.0         6.0        6.0     3.0   6.0
# dwarf fighter strength      20.0         6.0        6.0     5.0   4.0
# dwarf fighter   dexterity   20.0         6.0        6.0     6.0   4.0
#
#                            armor class  ...  medium  heavy  unarmed  simple  \
# character_build                         ...
# dwarf barbarian strength          13.0  ...     2.0    0.0      2.0     2.0
# dwarf fighter strength            13.0  ...     2.0    2.0      2.0     0.0
# dwarf fighter   dexterity         13.0  ...     2.0    2.0      2.0     0.0
#
#                            martial  advanced  other  magical tradition  \
# character_build
# dwarf barbarian strength       2.0       0.0    0.0                0.0
# dwarf fighter strength         2.0       0.0    0.0                0.0
# dwarf fighter   dexterity      2.0       0.0    0.0                0.0
#
#                            spell attack  spell dc
# character_build
# dwarf barbarian strength            0.0      10.0
# dwarf fighter strength              0.0      10.0
# dwarf fighter   dexterity           0.0      10.0
#
# [3 rows x 22 columns]

# %%
melee_attack_list= pd.read_csv('../output_data/melee_attack_output_all-builds.csv')

#clean up dataframe 
melee_attack_list= melee_attack_list.set_index('build', drop=True)
melee_attack_list= melee_attack_list.drop(columns=['Unnamed: 0'])

#adda  column for if it is a first or second action 
melee_attack_list['action_number']= [x.split(' ')[-1] for x in melee_attack_list['action']]

#view dataframe
melee_attack_list.head(3)
# Out:
#                           level                  action attack_roll_result  \
# build
# dwarf barbarian strength      1  str 1d4 melee attack 1        random_roll
# dwarf barbarian strength      1  str 1d4 melee attack 2        random_roll
# dwarf barbarian strength      1  str 1d6 melee attack 1        random_roll
#
#                           attack modifier  penalties  dmg_dice damage_type  \
# build
# dwarf barbarian strength              4.0          0         4       melee
# dwarf barbarian strength              4.0          5         4       melee
# dwarf barbarian strength              4.0          0         6       melee
#
#                           damage_output  target_ac  crit_ac action_number
# build
# dwarf barbarian strength            2.0       13.0     23.0             1
# dwarf barbarian strength            2.0       13.0     23.0             2
# dwarf barbarian strength            2.0       13.0     23.0             1

# %% [markdown]
# -----------

# %% [markdown]
# ## Simulate the average damage per round for each character build
# for EACH BUILD, simulate a round of combat by picking 2 actions from the action list, and using random number generators to estimate the outcome of those actions. Then three battle-performance metrics will be calucated from multi-round encounter simulation, and these metrics will be sampled by running over 100 encounters ("bootstraping" strategy)
#
# ### Three battle-performance metrics:
# 1) damage output (total and average)
# 3) rate of attack success
# 4) rate of crit attacks

# %%
build_skill.iloc[0]
build_name= build_skill.index[0]

# %%
def calculate_two_action_attack_output(action_list):
    first_action = action_list
    #Randomly pick action from action list using a random number generator 
    random_action_num= random.randrange(0, len(first_action))
    
    #pull out that action information 
    first_attack = first_action.iloc[random_action_num]
    
    #FIRST -> make an attack roll against a target with the SAME AC 
    d20_roll= random.randrange(1, 20)
    attack_roll = d20_roll + first_attack['attack modifier'] - first_attack['penalties']
    
    #check if the attack roll hits based on the target ac
    if attack_roll >= first_attack['target_ac']:
        attack_sucess_status= 1
        #Calculate damage
        #roll random damage dice 
        dmg_dice_roll= random.randrange(1, first_attack['dmg_dice'])
        #add damage proficiencies 
        total_damage= dmg_dice_roll + first_attack['damage_output']
    elif attack_roll >= first_attack['crit_ac']:
        attack_sucess_status= 2
        #calculate double damage 
    
        dmg_dice_roll_1= random.randrange(1, first_attack['dmg_dice'])
        roll_1= dmg_dice_roll_1 + first_attack['damage_output']
        dmg_dice_roll_2= random.randrange(1, first_attack['dmg_dice'])
        roll_2= dmg_dice_roll_2 + first_attack['damage_output']
        total_damage= roll_1 + roll_2
    else:
        attack_sucess_status= 0 
        #record no damage 
        total_damage= 0 

    return attack_sucess_status, total_damage

def encounter_simulation(build_name, num_round= 10, simulation_repeat= 100):
    #filter action list for only actions from a specific character build 
    build_action_list= melee_attack_list.loc[build_name]
    #organize into first and second action options
    first_action= build_action_list[build_action_list['action_number'] == '1']
    second_action= build_action_list[build_action_list['action_number'] == '2']

    #create output for simulation results
    simulation_outcome=pd.DataFrame(columns=['attack_sucess_1', 'attack_sucess_2', 'total_dmg', 'avg_dmg'])
    for simulation in range (simulation_repeat):
        count = simulation
        encounter_outcome=[]
        for round in range(total_num_round):
            attack_roll_1, total_damage_1 = calculate_two_action_attack_output(first_action)
            attack_roll_2, total_damage_2 = calculate_two_action_attack_output(second_action)
            total_round_damage= total_damage_1 + total_damage_2
        
            #save outcome to a list/dataframe 
            round_result= [round, attack_roll_1, attack_roll_2, total_round_damage]
            encounter_outcome.append(round_result)
    
        #Summarize the total 10-round encounter into a dataframe 
        encounter_result=pd.DataFrame(encounter_outcome, columns=['round', 'action_1_outcome', 'action_2_outcome', 'total_damage'])
        
        #calculate ecounter summary stats 
        attack_1_sucess= encounter_result['action_1_outcome'].mean()
        attack_2_sucess= encounter_result['action_2_outcome'].mean()
        total_dmg_output = encounter_result['total_damage'].sum()
        avg_dmg_output= encounter_result['total_damage'].mean()
        
        #save this as the final dataframe after 100 simulations 
        simulation_outcome.loc[f'encounter_{count}'] = [attack_1_sucess, attack_2_sucess, total_dmg_output, avg_dmg_output]

    #view final simulation outcome dataframe 
    return simulation_outcome

# %%
build_name= build_skill.index[0]

output_result= encounter_simulation(build_name)
output_result

fig,ax= plt.subplots()
ax = plt.hist(output_result['total_dmg'].to_list(), bins=20);
plt.title(f'{build_name} total damage across 10 rounds');
plt.xlabel('total damage over 10 rounds');

# %%
#filter out all character build option for a specific class 
chosen_class_list= build_skill['class'].unique()

for class_filter in chosen_class_list: 
    class_category_forbuild= class_filter
    #create a histogram overlapping based on each ancestry/ character build combination 
    group_by_class = build_skill[build_skill['class'] == class_category_forbuild]
    build_combo_for_class = group_by_class.index.to_list()
    
    fig,ax= plt.subplots() #subplots(2, 2)
    for char_build in build_combo_for_class:
        build_name= char_build
        output_result= encounter_simulation(build_name)
        build_ancestry= build_name.replace(class_category_forbuild, '')
        ax= plt.hist(output_result['total_dmg'].to_list(), bins=10, label=build_ancestry, alpha=0.7);
        title= f'{class_category_forbuild} total damage across 10 rounds'
        plt.title(title);
        plt.xlabel('total damage over 10 rounds');
        plt.legend(bbox_to_anchor=(1, 1), loc='upper right');
        fig.savefig(f'../output_figures/{title}.png');
    
    
    fig,ax= plt.subplots() #subplots(2, 2)
    for char_build in build_combo_for_class:
        build_name= char_build
        output_result= encounter_simulation(build_name)
        build_ancestry= build_name.replace(class_category_forbuild, '')
        ax= plt.hist(output_result['avg_dmg'].to_list(), bins=10, label=build_ancestry, alpha=0.7);
        title= f'{class_category_forbuild} average damage across 10 rounds'
        plt.title(title);
        plt.xlabel('avg damage over 10 rounds');
        plt.legend(bbox_to_anchor=(1, 1), loc='upper right')
        fig.savefig(f'../output_figures/{title}.png')
    
    fig,ax= plt.subplots() #subplots(2, 2)
    for char_build in build_combo_for_class:
        build_name= char_build
        output_result= encounter_simulation(build_name)
        build_ancestry= build_name.replace(class_category_forbuild, '')
        ax= plt.hist(output_result['avg_dmg'].to_list(), bins=10, label=build_ancestry, alpha=0.7);
        title= f'{class_category_forbuild} average damage across 10 rounds'
        plt.title(title);
        plt.xlabel('avg damage over 10 rounds');
        plt.legend(bbox_to_anchor=(1, 1), loc='upper right')
        fig.savefig(f'../output_figures/{title}.png')
    
    fig,ax= plt.subplots() #subplots(2, 2)
    for char_build in build_combo_for_class:
        build_name= char_build
        output_result= encounter_simulation(build_name)
        build_ancestry= build_name.replace(class_category_forbuild, '')
        ax= plt.hist(output_result['attack_sucess_1'].to_list(), bins=10, label=build_ancestry, alpha=0.7);
        title= f'{class_category_forbuild} first attack sucess across 10 rounds'
        plt.title(title);
        plt.xlabel('attack sucess over 10 rounds');
        plt.legend(bbox_to_anchor=(1, 1), loc='upper right')
        fig.savefig(f'../output_figures/{title}.png')
